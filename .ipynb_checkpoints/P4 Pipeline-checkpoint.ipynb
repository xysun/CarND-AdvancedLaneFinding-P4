# %%
# imports

import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
import pickle

# load calibration matrix
with open('calibration.pickle', 'rb') as f:
    mtx,dist = pickle.load(f)

# %%
# load perspective transform
with open('perspective.pickle', 'rb') as f:
    M,Minv = pickle.load(f)

# %%
def region_of_interest(img, vertices):
    """
    Applies an image mask. Copied from P1.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

# %%
# pipeline components
def undistort(img):
    return cv2.undistort(img, mtx, dist, None, mtx)

def color_threshold(img):
    # get RGB and HLS
    hls = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)

    R = img[:,:,0]
    G = img[:,:,1]
    B = img[:,:,2]

    H = hls[:,:,0]
    L = hls[:,:,1]
    S = hls[:,:,2]

    #R threshold
    r_thresh = (200, 255)
    r_binary = np.zeros_like(R)
    r_binary[(R > r_thresh[0]) & (R <= r_thresh[1])] = 1

    #S threshold
    s_thresh = (90, 255)
    s_binary = np.zeros_like(S)
    s_binary[(S > s_thresh[0]) & (S <= s_thresh[1])] = 1

    # stack R and S
    combined_binary = np.zeros_like(S)
    combined_binary[((s_binary == 1) & (r_binary == 1))] = 1

    return combined_binary

def region_mask(img):
    buffer_bucket = 15

    xsize,ysize = img.shape[1],img.shape[0]

    x_buffer    = xsize / buffer_bucket

    lower_left  = (x_buffer,       ysize)
    lower_right = (xsize-x_buffer, ysize)
    top_left    = (xsize/2-10,     ysize/2+45) # normally the horizon is towards the bottom half
    top_right   = (xsize/2+10,     ysize/2+45)

    vertices = np.array([[
                lower_left,
                top_left,
                top_right,
                lower_right
            ]], dtype=np.int32)

    region = region_of_interest(img, vertices)

    return region

def perspective_transform(img):
    
    img_size = (img.shape[1], img.shape[0])
    warped = cv2.warpPerspective(img, M, img_size, flags=cv2.INTER_LINEAR)
    return warped

def get_curvature(leftx, lefty, rightx, righty):
    # Define conversions in x and y from pixels space to meters
    ym_per_pix = 30/720 # meters per pixel in y dimension
    xm_per_pix = 3.7/700 # meters per pixel in x dimension
    
    y_eval_left = np.max(lefty)
    y_eval_right = np.max(righty)

    # Fit new polynomials to x,y in world space
    left_fit_cr = np.polyfit(lefty*ym_per_pix, leftx*xm_per_pix, 2)
    right_fit_cr = np.polyfit(righty*ym_per_pix, rightx*xm_per_pix, 2)
    # Calculate the new radii of curvature
    left_curverad = ((1 + (2*left_fit_cr[0]*y_eval_left*ym_per_pix + left_fit_cr[1])**2)**1.5) / np.absolute(2*left_fit_cr[0])
    right_curverad = ((1 + (2*right_fit_cr[0]*y_eval_right*ym_per_pix + right_fit_cr[1])**2)**1.5) / np.absolute(2*right_fit_cr[0])
    # Now our radius of curvature is in meters
    return left_curverad, right_curverad

def histogram_search(img):
    # get histogram
    histogram = np.sum(img[int(img.shape[0]/2):,:], axis=0)
    
    # fit polynomial
    # Find the peak of the left and right halves of the histogram
    # These will be the starting point for the left and right lines
    midpoint = np.int(histogram.shape[0]/2)
    leftx_base = np.argmax(histogram[:midpoint])
    rightx_base = np.argmax(histogram[midpoint:]) + midpoint

    # Choose the number of sliding windows
    nwindows = 9
    # Set height of windows
    window_height = np.int(img.shape[0]/nwindows)
    # Identify the x and y positions of all nonzero pixels in the image
    nonzero = img.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    # Current positions to be updated for each window
    leftx_current = leftx_base
    rightx_current = rightx_base
    # Set the width of the windows +/- margin
    margin = 100
    # Set minimum number of pixels found to recenter window
    minpix = 50
    # Create empty lists to receive left and right lane pixel indices
    left_lane_inds = []
    right_lane_inds = []

    window_size = 100
    
    # Step through the windows one by one
    for window in range(nwindows):
        # Identify window boundaries in x and y (and right and left)
        win_y_low = img.shape[0] - (window+1)*window_size
        win_y_high = img.shape[0] - window*window_size
        win_xleft_low = leftx_current - margin
        win_xleft_high = leftx_current + margin
        win_xright_low = rightx_current - margin
        win_xright_high = rightx_current + margin
        # Identify the nonzero pixels in x and y within the window
        good_left_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & (nonzerox >= win_xleft_low) & (nonzerox < win_xleft_high)).nonzero()[0]
        good_right_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & (nonzerox >= win_xright_low) & (nonzerox < win_xright_high)).nonzero()[0]
        # Append these indices to the lists
        left_lane_inds.append(good_left_inds)
        right_lane_inds.append(good_right_inds)
        # If you found > minpix pixels, recenter next window on their mean position
        if len(good_left_inds) > minpix:
            leftx_current = np.int(np.mean(nonzerox[good_left_inds]))
        if len(good_right_inds) > minpix:        
            rightx_current = np.int(np.mean(nonzerox[good_right_inds]))

    # Concatenate the arrays of indices
    left_lane_inds = np.concatenate(left_lane_inds)
    right_lane_inds = np.concatenate(right_lane_inds)

    # Extract left and right line pixel positions
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds] 
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds]
    
    return leftx, lefty, rightx, righty
    

def histogram_search_next(img, left_fit, right_fit):
    print("searching from last histogram")
    # carry over from previous fit
    nonzero = img.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    margin = 100
    left_lane_inds = ((nonzerox > (left_fit[0]*(nonzeroy**2) + left_fit[1]*nonzeroy + left_fit[2] - margin)) & (nonzerox < (left_fit[0]*(nonzeroy**2) + left_fit[1]*nonzeroy + left_fit[2] + margin))) 
    right_lane_inds = ((nonzerox > (right_fit[0]*(nonzeroy**2) + right_fit[1]*nonzeroy + right_fit[2] - margin)) & (nonzerox < (right_fit[0]*(nonzeroy**2) + right_fit[1]*nonzeroy + right_fit[2] + margin)))  

    # Again, extract left and right line pixel positions
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds] 
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds]
    
    return leftx, lefty, rightx, righty



def draw_back(undistorted, warped, left_fit, right_fit):
    # Generate x and y values for plotting
    fity = np.linspace(0, img.shape[0]-1, img.shape[0] )
    fit_leftx = left_fit[0]*fity**2 + left_fit[1]*fity + left_fit[2]
    fit_rightx = right_fit[0]*fity**2 + right_fit[1]*fity + right_fit[2]
    
    
    # Create an image to draw the lines on
    warp_zero = np.zeros_like(warped).astype(np.uint8)
    color_warp = np.dstack((warp_zero, warp_zero, warp_zero))

    # Recast the x and y points into usable format for cv2.fillPoly()
    pts_left = np.array([np.transpose(np.vstack([fit_leftx, fity]))])
    pts_right = np.array([np.flipud(np.transpose(np.vstack([fit_rightx, fity])))])
    pts = np.hstack((pts_left, pts_right))

    # Draw the lane onto the warped blank image
    cv2.fillPoly(color_warp, np.int_([pts]), (0,255, 0))

    # Warp the blank back to original image space using inverse perspective matrix (Minv)
    newwarp = cv2.warpPerspective(color_warp, Minv, (img.shape[1], img.shape[0])) 
    # Combine the result with the original image
    result = cv2.addWeighted(undistorted, 1, newwarp, 0.3, 0)
    
    return result

# %%
# Define a class to receive the characteristics of each line detection
class Line():
    def __init__(self):
        # first pass?
        self.first_pass = True
        #radius of curvature of the line in some units
        self.curvature_left = None 
        self.curvature_right = None
        #current fit
        self.best_fit_lefts = []
        self.best_fit_rights = []
        
        # below are not used for now

        # was the line detected in the last iteration?
        self.detected = False  
        # x values of the last n fits of the line
        self.recent_xfitted = [] 
        #average x values of the fitted line over the last n iterations
        self.bestx = None     
        #polynomial coefficients averaged over the last n iterations
        self.best_fit = None  
        #distance in meters of vehicle center from the line
        self.line_base_pos = None 
        #difference in fit coefficients between last and new fits
        self.diffs = np.array([0,0,0], dtype='float') 
        #x values for detected line pixels
        self.allx = None  
        #y values for detected line pixels
        self.ally = None
        
    def get_histogram_search(self, warped):
        if self.first_pass:
            return histogram_search(warped)
        else:
            return histogram_search_next(warped, self.current_fit_x, self.current_fit_y)
    
    def get_fit(self, leftx, lefty, rightx, righty):
        if self.first_pass:
            self.first_pass = False
            left_fit = np.polyfit(lefty, leftx, 2)
            right_fit = np.polyfit(righty, rightx, 2)
            # save curvature
            self.curvature_left, self.curvature_right = get_curvature(leftx,lefty,rightx,righty)
            # save fit
            self.best_fit_lefts.append(left_fit)
            self.best_fit_rights.append(right_fit)
            return left_fit, right_fit
        else:
            margin = 400
            offset = 5
            try:
                curvature = get_curvature(leftx,lefty,rightx,righty)
                if abs(curvature[0] - self.curvature_left) < margin:
                    print("updating left fit, last curvature:", self.curvature_left, " new curvature", curvature[0])
                    self.curvature_left = curvature[0]
                    self.best_fit_lefts.append(np.polyfit(lefty, leftx, 2))
                    print("good lefts:", len(self.best_fit_lefts))
                if abs(curvature[1] - self.curvature_right) < margin:
                    print("updating right fit, last curvature:", self.curvature_right, " new curvature", curvature[1])
                    self.curvature_right = curvature[1]
                    self.best_fit_rights.append(np.polyfit(righty,rightx,2))
                    print("good rights:", len(self.best_fit_rights))
            except:
                pass
                        
            return np.mean(np.array(self.best_fit_lefts[-1*offset:]), axis=0).tolist(),np.mean(np.array(self.best_fit_rights[-1*offset:]), axis=0).tolist()

# %%
def pipeline(img, line):
    
    #undistort
    undistorted = undistort(img)
    
    #color threshold
    combined_binary = color_threshold(undistorted)
    
    # region of interest
    region = region_mask(combined_binary)
    
    # perspective transform
    warped = perspective_transform(region)
    
    # get histogram search
    leftx,lefty,rightx,righty = line.get_histogram_search(warped)
    print("leftx:", len(leftx), "rightx:", len(rightx))
    
    line.current_fit_x, line.current_fit_y = line.get_fit(leftx,lefty,rightx,righty)
    
    # draw back
    result = draw_back(undistorted, warped, line.current_fit_x, line.current_fit_y)
    
    return result

# %%
import glob
images = glob.glob('test_images/*.jpg')

line = Line()

for idx, fname in enumerate(images):
    line = Line()
    img = mpimg.imread(fname)
    print("applying lane to image...", fname)
    plt.figure(idx+1)
    plt.subplot(1,2,1)
    plt.title("original")
    plt.imshow(img)
    
    lane = pipeline(img, line)
    plt.subplot(1,2,2)
    plt.title("lane")
    plt.imshow(lane, cmap='gray')
    plt.show()
# Out:
# applying lane to image... test_images/straight_lines1.jpg
# leftx: 9215 rightx: 943
# applying lane to image... test_images/straight_lines2.jpg
# leftx: 1884 rightx: 5980
# applying lane to image... test_images/test1.jpg
# leftx: 43203 rightx: 2944
# applying lane to image... test_images/test2.jpg
# leftx: 10855 rightx: 889
# applying lane to image... test_images/test3.jpg
# leftx: 8442 rightx: 1613
# applying lane to image... test_images/test4.jpg
# leftx: 44517 rightx: 3166
# applying lane to image... test_images/test5.jpg
# leftx: 5189 rightx: 1393
# applying lane to image... test_images/test6.jpg
# leftx: 6317 rightx: 1718

# %%
line = Line()

idx = 0
fname = 'project_video_10s/project_video_10s 05.jpg'
img = mpimg.imread(fname)
lane = pipeline(img, line)
plt.imshow(lane)
# Out:
# leftx: 9777 rightx: 610

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
# %matplotlib inline
line = Line()
def process_image(img):
    global line
    return pipeline(img, line)

# %%
output = 'project_video_output_4s.mp4'
clip1 = VideoFileClip("project_video_4s.mp4")
clip = clip1.fl_image(process_image)
# %time clip.write_videofile(output, audio=False)
# Out:
# leftx: 11241 rightx: 1655
# [MoviePy] >>>> Building video project_video_output_4s.mp4
# [MoviePy] Writing video project_video_output_4s.mp4
#   0%|          | 0/102 [00:00<?, ?it/s]
# searching from last histogram
# leftx: 11241 rightx: 1655
# updating left fit, last curvature: 516.911005821  new curvature 516.911005821
# good lefts: 2
# updating right fit, last curvature: 846.463412252  new curvature 846.463412252
# good rights: 2
#   2%|▏         | 2/102 [00:00<00:20,  4.87it/s]
# searching from last histogram
# leftx: 11331 rightx: 1793
# updating left fit, last curvature: 516.911005821  new curvature 508.28033158
# good lefts: 3
# updating right fit, last curvature: 846.463412252  new curvature 625.563277203
# good rights: 3
#   3%|▎         | 3/102 [00:00<00:20,  4.89it/s]
# searching from last histogram
# leftx: 11212 rightx: 1854
# updating left fit, last curvature: 508.28033158  new curvature 502.309710674
# good lefts: 4
# updating right fit, last curvature: 625.563277203  new curvature 779.909117578
# good rights: 4
# searching from last histogram
#   4%|▍         | 4/102 [00:00<00:19,  4.91it/s]
# leftx: 10960 rightx: 1962
# updating left fit, last curvature: 502.309710674  new curvature 504.930683061
# good lefts: 5
# updating right fit, last curvature: 779.909117578  new curvature 756.518928033
# good rights: 5
#   5%|▍         | 5/102 [00:01<00:19,  4.87it/s]
# searching from last histogram
# leftx: 10365 rightx: 1690
# updating left fit, last curvature: 504.930683061  new curvature 496.960964271
# good lefts: 6
# updating right fit, last curvature: 756.518928033  new curvature 598.736578333
# good rights: 6
# searching from last histogram
# leftx: 10380 rightx: 1289
# updating left fit, last curvature: 496.960964271  new curvature 502.547737522
# good lefts: 7
# updating right fit, last curvature: 598.736578333  new curvature 590.438743436
# good rights: 7
#   7%|▋         | 7/102 [00:01<00:19,  4.97it/s]
# searching from last histogram
# leftx: 10539 rightx: 1025
# updating left fit, last curvature: 502.547737522  new curvature 532.606687036
# good lefts: 8
# updating right fit, last curvature: 590.438743436  new curvature 517.724083873
# good rights: 8
# searching from last histogram
# leftx: 10186 rightx: 737
# updating left fit, last curvature: 532.606687036  new curvature 527.785163772
# good lefts: 9
#   9%|▉         | 9/102 [00:01<00:18,  5.06it/s]
# searching from last histogram
# leftx: 10403 rightx: 883
# updating left fit, last curvature: 527.785163772  new curvature 558.409933175
# good lefts: 10
# searching from last histogram
# leftx: 10895 rightx: 992
# updating left fit, last curvature: 558.409933175  new curvature 574.073956698
# good lefts: 11
# updating right fit, last curvature: 517.724083873  new curvature 688.044008474
# good rights: 9
#  11%|█         | 11/102 [00:02<00:17,  5.07it/s]
# searching from last histogram
# leftx: 10603 rightx: 1094
# updating left fit, last curvature: 574.073956698  new curvature 576.348929091
# good lefts: 12
# updating right fit, last curvature: 688.044008474  new curvature 865.096272392
# good rights: 10
# searching from last histogram
# leftx: 10883 rightx: 1237
# updating left fit, last curvature: 576.348929091  new curvature 632.195773121
# good lefts: 13
# updating right fit, last curvature: 865.096272392  new curvature 629.862545846
# good rights: 11
#  13%|█▎        | 13/102 [00:02<00:17,  5.09it/s]
# searching from last histogram
# leftx: 10843 rightx: 1274
# updating left fit, last curvature: 632.195773121  new curvature 642.752601222
# good lefts: 14
# updating right fit, last curvature: 629.862545846  new curvature 583.192736843
# good rights: 12
# searching from last histogram
# leftx: 10859 rightx: 1438
# updating left fit, last curvature: 642.752601222  new curvature 653.912182538
# good lefts: 15
# updating right fit, last curvature: 583.192736843  new curvature 587.835442978
# good rights: 13
#  15%|█▍        | 15/102 [00:02<00:17,  5.12it/s]
# searching from last histogram
# leftx: 10739 rightx: 1571
# updating left fit, last curvature: 653.912182538  new curvature 604.660421243
# good lefts: 16
# updating right fit, last curvature: 587.835442978  new curvature 603.788171829
# good rights: 14
# searching from last histogram
# leftx: 10696 rightx: 1563
# updating left fit, last curvature: 604.660421243  new curvature 589.29345669
# good lefts: 17
# updating right fit, last curvature: 603.788171829  new curvature 634.51642788
# good rights: 15
#  17%|█▋        | 17/102 [00:03<00:16,  5.14it/s]
# searching from last histogram
# leftx: 10303 rightx: 1628
# updating left fit, last curvature: 589.29345669  new curvature 580.687842751
# good lefts: 18
# updating right fit, last curvature: 634.51642788  new curvature 615.460279545
# good rights: 16
# searching from last histogram
# leftx: 10199 rightx: 1450
# updating left fit, last curvature: 580.687842751  new curvature 578.160780177
# good lefts: 19
# updating right fit, last curvature: 615.460279545  new curvature 887.629794133
# good rights: 17
#  19%|█▊        | 19/102 [00:03<00:16,  5.06it/s]
# searching from last histogram
# leftx: 10631 rightx: 1121
# updating left fit, last curvature: 578.160780177  new curvature 597.104240363
# good lefts: 20
# searching from last histogram
#  20%|█▉        | 20/102 [00:03<00:16,  5.01it/s]
# leftx: 10423 rightx: 872
# updating left fit, last curvature: 597.104240363  new curvature 621.077986879
# good lefts: 21
# updating right fit, last curvature: 887.629794133  new curvature 1235.14650029
# good rights: 18
# searching from last histogram
# leftx: 10670 rightx: 743
# updating left fit, last curvature: 621.077986879  new curvature 658.968399811
# good lefts: 22
# updating right fit, last curvature: 1235.14650029  new curvature 1225.6240991
# good rights: 19
#  22%|██▏       | 22/102 [00:04<00:15,  5.02it/s]
# searching from last histogram
# leftx: 10861 rightx: 930
# updating left fit, last curvature: 658.968399811  new curvature 705.343058308
# good lefts: 23
# searching from last histogram
# leftx: 11033 rightx: 974
# updating left fit, last curvature: 705.343058308  new curvature 727.890612409
# good lefts: 24
#  24%|██▎       | 24/102 [00:04<00:15,  5.02it/s]
# searching from last histogram
# leftx: 10605 rightx: 1059
# updating left fit, last curvature: 727.890612409  new curvature 660.045415384
# good lefts: 25
# searching from last histogram
#  25%|██▍       | 25/102 [00:04<00:15,  5.01it/s]
# leftx: 10883 rightx: 1129
# updating left fit, last curvature: 660.045415384  new curvature 583.328620268
# good lefts: 26
# searching from last histogram
# leftx: 10981 rightx: 1099
# updating left fit, last curvature: 583.328620268  new curvature 604.400246569
# good lefts: 27
#  26%|██▋       | 27/102 [00:05<00:14,  5.12it/s]
# searching from last histogram
# leftx: 10884 rightx: 1315
# updating left fit, last curvature: 604.400246569  new curvature 587.212065309
# good lefts: 28
# searching from last histogram
# leftx: 11241 rightx: 1355
# updating left fit, last curvature: 587.212065309  new curvature 610.40875337
# good lefts: 29
#  28%|██▊       | 29/102 [00:05<00:14,  5.02it/s]
# searching from last histogram
# leftx: 11130 rightx: 1719
# updating left fit, last curvature: 610.40875337  new curvature 565.596267726
# good lefts: 30
# searching from last histogram
# leftx: 10823 rightx: 1478
# updating left fit, last curvature: 565.596267726  new curvature 502.545285804
# good lefts: 31
#  30%|███       | 31/102 [00:06<00:13,  5.11it/s]
# searching from last histogram
# leftx: 10781 rightx: 1476
# updating left fit, last curvature: 502.545285804  new curvature 460.570996131
# good lefts: 32
# searching from last histogram
# leftx: 10559 rightx: 1054
# updating left fit, last curvature: 460.570996131  new curvature 422.726438969
# good lefts: 33
#  32%|███▏      | 33/102 [00:06<00:13,  5.06it/s]
# searching from last histogram
# leftx: 10315 rightx: 693
# updating left fit, last curvature: 422.726438969  new curvature 423.262872097
# good lefts: 34
# searching from last histogram
# leftx: 10537 rightx: 688
# updating left fit, last curvature: 423.262872097  new curvature 405.617918367
# good lefts: 35
# updating right fit, last curvature: 1225.6240991  new curvature 1613.72042626
# good rights: 20
#  34%|███▍      | 35/102 [00:06<00:13,  5.05it/s]
# searching from last histogram
# leftx: 10256 rightx: 731
# updating left fit, last curvature: 405.617918367  new curvature 400.290942582
# good lefts: 36
# updating right fit, last curvature: 1613.72042626  new curvature 1355.089838
# good rights: 21
# searching from last histogram
# leftx: 10024 rightx: 840
# updating left fit, last curvature: 400.290942582  new curvature 392.310121525
# good lefts: 37
# updating right fit, last curvature: 1355.089838  new curvature 1221.2480381
# good rights: 22
#  36%|███▋      | 37/102 [00:07<00:12,  5.16it/s]
# searching from last histogram
# leftx: 9776 rightx: 998
# updating left fit, last curvature: 392.310121525  new curvature 388.034778909
# good lefts: 38
# updating right fit, last curvature: 1221.2480381  new curvature 1000.81394892
# good rights: 23
# searching from last histogram
# leftx: 10255 rightx: 1018
# updating left fit, last curvature: 388.034778909  new curvature 373.294634746
# good lefts: 39
# updating right fit, last curvature: 1000.81394892  new curvature 638.066100575
# good rights: 24
#  38%|███▊      | 39/102 [00:07<00:12,  5.22it/s]
# searching from last histogram
# leftx: 10205 rightx: 1045
# updating left fit, last curvature: 373.294634746  new curvature 369.548512065
# good lefts: 40
# updating right fit, last curvature: 638.066100575  new curvature 584.789306759
# good rights: 25
# searching from last histogram
# leftx: 10060 rightx: 1198
# updating left fit, last curvature: 369.548512065  new curvature 380.567758917
# good lefts: 41
# updating right fit, last curvature: 584.789306759  new curvature 557.364493978
# good rights: 26
#  40%|████      | 41/102 [00:08<00:11,  5.21it/s]
# searching from last histogram
# leftx: 9796 rightx: 1363
# updating left fit, last curvature: 380.567758917  new curvature 385.219157617
# good lefts: 42
# updating right fit, last curvature: 557.364493978  new curvature 625.909244946
# good rights: 27
# searching from last histogram
# leftx: 9751 rightx: 1588
# updating left fit, last curvature: 385.219157617  new curvature 393.570305599
# good lefts: 43
# updating right fit, last curvature: 625.909244946  new curvature 628.550494603
# good rights: 28
#  42%|████▏     | 43/102 [00:08<00:11,  5.06it/s]
# searching from last histogram
# leftx: 9800 rightx: 1357
# updating left fit, last curvature: 393.570305599  new curvature 401.639642847
# good lefts: 44
# updating right fit, last curvature: 628.550494603  new curvature 700.901371251
# good rights: 29
# searching from last histogram
# leftx: 10351 rightx: 1122
# updating left fit, last curvature: 401.639642847  new curvature 426.637551031
#  43%|████▎     | 44/102 [00:08<00:11,  5.02it/s]
# good lefts: 45
# updating right fit, last curvature: 700.901371251  new curvature 568.486295498
# good rights: 30
# searching from last histogram
# leftx: 10427 rightx: 905
# updating left fit, last curvature: 426.637551031  new curvature 445.460002315
# good lefts: 46
# updating right fit, last curvature: 568.486295498  new curvature 506.925830884
# good rights: 31
#  45%|████▌     | 46/102 [00:09<00:11,  5.05it/s]
# searching from last histogram
# leftx: 10495 rightx: 750
# updating left fit, last curvature: 445.460002315  new curvature 457.958856397
# good lefts: 47
# searching from last histogram
#  46%|████▌     | 47/102 [00:09<00:10,  5.04it/s]
# leftx: 10614 rightx: 822
# updating left fit, last curvature: 457.958856397  new curvature 481.323834032
# good lefts: 48
# searching from last histogram
# leftx: 10458 rightx: 917
# updating left fit, last curvature: 481.323834032  new curvature 492.153637052
# good lefts: 49
#  48%|████▊     | 49/102 [00:09<00:10,  5.09it/s]
# searching from last histogram
# leftx: 10571 rightx: 1023
# updating left fit, last curvature: 492.153637052  new curvature 524.619569945
# good lefts: 50
# searching from last histogram
# leftx: 10474 rightx: 1070
# updating left fit, last curvature: 524.619569945  new curvature 533.971288666
#  49%|████▉     | 50/102 [00:09<00:10,  5.06it/s]
# good lefts: 51
# searching from last histogram
# leftx: 10270 rightx: 1093
# updating left fit, last curvature: 533.971288666  new curvature 555.445253076
# good lefts: 52
# updating right fit, last curvature: 506.925830884  new curvature 574.796503915
# good rights: 32
#  51%|█████     | 52/102 [00:10<00:09,  5.12it/s]
# searching from last histogram
# leftx: 10187 rightx: 1180
# updating left fit, last curvature: 555.445253076  new curvature 555.851581634
# good lefts: 53
# updating right fit, last curvature: 574.796503915  new curvature 532.501501652
# good rights: 33
# searching from last histogram
# leftx: 10118 rightx: 1303
# updating left fit, last curvature: 555.851581634  new curvature 570.233515693
# good lefts: 54
# updating right fit, last curvature: 532.501501652  new curvature 566.02625115
# good rights: 34
#  53%|█████▎    | 54/102 [00:10<00:09,  5.15it/s]
# searching from last histogram
# leftx: 10231 rightx: 1551
# updating left fit, last curvature: 570.233515693  new curvature 582.657769641
# good lefts: 55
# updating right fit, last curvature: 566.02625115  new curvature 597.124186183
# good rights: 35
# searching from last histogram
# leftx: 10166 rightx: 1596
# updating left fit, last curvature: 582.657769641  new curvature 598.02402908
# good lefts: 56
# updating right fit, last curvature: 597.124186183  new curvature 567.817650086
# good rights: 36
#  55%|█████▍    | 56/102 [00:11<00:09,  5.08it/s]
# searching from last histogram
# leftx: 10327 rightx: 1308
# updating left fit, last curvature: 598.02402908  new curvature 622.843575608
# good lefts: 57
# updating right fit, last curvature: 567.817650086  new curvature 525.052111268
# good rights: 37
# searching from last histogram
# leftx: 10175 rightx: 1006
# updating left fit, last curvature: 622.843575608  new curvature 644.920359173
# good lefts: 58
# updating right fit, last curvature: 525.052111268  new curvature 516.964264905
# good rights: 38
#  57%|█████▋    | 58/102 [00:11<00:08,  5.10it/s]
# searching from last histogram
# leftx: 10263 rightx: 770
# updating left fit, last curvature: 644.920359173  new curvature 652.654138302
# good lefts: 59
# updating right fit, last curvature: 516.964264905  new curvature 430.744966299
# good rights: 39
# searching from last histogram
#  58%|█████▊    | 59/102 [00:11<00:08,  5.05it/s]
# leftx: 10100 rightx: 765
# updating left fit, last curvature: 652.654138302  new curvature 631.942327151
# good lefts: 60
# searching from last histogram
# leftx: 9850 rightx: 809
# updating left fit, last curvature: 631.942327151  new curvature 606.036859953
# good lefts: 61
#  60%|█████▉    | 61/102 [00:12<00:08,  5.11it/s]
# searching from last histogram
# leftx: 9939 rightx: 1107
# updating left fit, last curvature: 606.036859953  new curvature 612.37854465
# good lefts: 62
# updating right fit, last curvature: 430.744966299  new curvature 688.770963142
# good rights: 40
# searching from last histogram
# leftx: 9706 rightx: 1177
# updating left fit, last curvature: 612.37854465  new curvature 586.445739135
# good lefts: 63
# updating right fit, last curvature: 688.770963142  new curvature 728.666563004
# good rights: 41
#  62%|██████▏   | 63/102 [00:12<00:07,  5.17it/s]
# searching from last histogram
# leftx: 9802 rightx: 1199
# updating left fit, last curvature: 586.445739135  new curvature 594.15899315
# good lefts: 64
# updating right fit, last curvature: 728.666563004  new curvature 580.48272309
# good rights: 42
# searching from last histogram
# leftx: 9876 rightx: 1330
# updating left fit, last curvature: 594.15899315  new curvature 585.941623852
# good lefts: 65
# updating right fit, last curvature: 580.48272309  new curvature 587.335081322
# good rights: 43
#  64%|██████▎   | 65/102 [00:12<00:07,  5.16it/s]
# searching from last histogram
# leftx: 10029 rightx: 1488
# updating left fit, last curvature: 585.941623852  new curvature 590.249988032
# good lefts: 66
# updating right fit, last curvature: 587.335081322  new curvature 610.065137898
# good rights: 44
# searching from last histogram
# leftx: 9895 rightx: 1596
# updating left fit, last curvature: 590.249988032  new curvature 572.494836366
# good lefts: 67
# updating right fit, last curvature: 610.065137898  new curvature 663.122201166
#  65%|██████▍   | 66/102 [00:12<00:07,  5.11it/s]
# good rights: 45
#  66%|██████▌   | 67/102 [00:13<00:06,  5.03it/s]
# searching from last histogram
# leftx: 9853 rightx: 1644
# updating left fit, last curvature: 572.494836366  new curvature 592.779318986
# good lefts: 68
# updating right fit, last curvature: 663.122201166  new curvature 727.659777208
# good rights: 46
# searching from last histogram
#  67%|██████▋   | 68/102 [00:13<00:06,  5.03it/s]
# leftx: 9848 rightx: 1378
# updating left fit, last curvature: 592.779318986  new curvature 595.763479121
# good lefts: 69
# searching from last histogram
# leftx: 9975 rightx: 1108
# updating left fit, last curvature: 595.763479121  new curvature 567.380431529
#  68%|██████▊   | 69/102 [00:13<00:06,  5.03it/s]
# good lefts: 70
# updating right fit, last curvature: 727.659777208  new curvature 1061.5380822
# good rights: 47
# searching from last histogram
# leftx: 9978 rightx: 713
# updating left fit, last curvature: 567.380431529  new curvature 591.7503557
# good lefts: 71
#  70%|██████▉   | 71/102 [00:13<00:06,  5.11it/s]
# searching from last histogram
# leftx: 9994 rightx: 574
# updating left fit, last curvature: 591.7503557  new curvature 597.038848654
# good lefts: 72
# searching from last histogram
# leftx: 10176 rightx: 759
#  71%|███████   | 72/102 [00:14<00:05,  5.07it/s]
# updating left fit, last curvature: 597.038848654  new curvature 622.522535604
# good lefts: 73
# updating right fit, last curvature: 1061.5380822  new curvature 898.022356556
# good rights: 48
# searching from last histogram
# leftx: 10217 rightx: 871
# updating left fit, last curvature: 622.522535604  new curvature 644.986846646
# good lefts: 74
# updating right fit, last curvature: 898.022356556  new curvature 498.168082459
# good rights: 49
#  73%|███████▎  | 74/102 [00:14<00:05,  5.06it/s]
# searching from last histogram
# leftx: 10203 rightx: 944
# updating left fit, last curvature: 644.986846646  new curvature 674.907142206
# good lefts: 75
# searching from last histogram
# leftx: 10402 rightx: 1130
# updating left fit, last curvature: 674.907142206  new curvature 725.657838849
#  74%|███████▎  | 75/102 [00:14<00:05,  5.07it/s]
# good lefts: 76
# searching from last histogram
# leftx: 10235 rightx: 1147
# updating left fit, last curvature: 725.657838849  new curvature 732.856156102
# good lefts: 77
# updating right fit, last curvature: 498.168082459  new curvature 700.244012936
# good rights: 50
#  75%|███████▌  | 77/102 [00:15<00:04,  5.14it/s]
# searching from last histogram
# leftx: 10525 rightx: 1316
# updating left fit, last curvature: 732.856156102  new curvature 825.239625964
# good lefts: 78
# updating right fit, last curvature: 700.244012936  new curvature 729.153220862
# good rights: 51
# searching from last histogram
# leftx: 10711 rightx: 1594
# updating left fit, last curvature: 825.239625964  new curvature 873.517194207
# good lefts: 79
# updating right fit, last curvature: 729.153220862  new curvature 788.484913283
# good rights: 52
#  77%|███████▋  | 79/102 [00:15<00:04,  5.12it/s]
# searching from last histogram
# leftx: 10624 rightx: 1775
# updating left fit, last curvature: 873.517194207  new curvature 916.451813859
# good lefts: 80
# updating right fit, last curvature: 788.484913283  new curvature 829.804240704
# good rights: 53
# searching from last histogram
# leftx: 10621 rightx: 1694
# updating left fit, last curvature: 916.451813859  new curvature 879.555105185
# good lefts: 81
# updating right fit, last curvature: 829.804240704  new curvature 800.294757378
# good rights: 54
#  79%|███████▉  | 81/102 [00:15<00:04,  5.11it/s]
# searching from last histogram
# leftx: 10564 rightx: 1389
# updating left fit, last curvature: 879.555105185  new curvature 854.112280933
# good lefts: 82
# updating right fit, last curvature: 800.294757378  new curvature 839.002815854
# good rights: 55
# searching from last histogram
# leftx: 10608 rightx: 1059
# updating left fit, last curvature: 854.112280933  new curvature 821.317297797
# good lefts: 83
# updating right fit, last curvature: 839.002815854  new curvature 628.736099323
# good rights: 56
#  81%|████████▏ | 83/102 [00:16<00:03,  5.13it/s]
# searching from last histogram
# leftx: 10725 rightx: 741
# updating left fit, last curvature: 821.317297797  new curvature 798.512274228
# good lefts: 84
# updating right fit, last curvature: 628.736099323  new curvature 589.929418738
# good rights: 57
# searching from last histogram
# leftx: 11133 rightx: 744
# updating left fit, last curvature: 798.512274228  new curvature 836.500471305
# good lefts: 85
#  83%|████████▎ | 85/102 [00:16<00:03,  5.16it/s]
# searching from last histogram
# leftx: 10918 rightx: 785
# updating left fit, last curvature: 836.500471305  new curvature 776.533545091
# good lefts: 86
# searching from last histogram
# leftx: 11053 rightx: 1043
# updating left fit, last curvature: 776.533545091  new curvature 714.353983866
# good lefts: 87
# updating right fit, last curvature: 589.929418738  new curvature 742.466834628
# good rights: 58
#  85%|████████▌ | 87/102 [00:17<00:02,  5.18it/s]
# searching from last histogram
# leftx: 10714 rightx: 1084
# updating left fit, last curvature: 714.353983866  new curvature 617.309175379
# good lefts: 88
# updating right fit, last curvature: 742.466834628  new curvature 808.4048302
# good rights: 59
# searching from last histogram
# leftx: 10677 rightx: 1287
# updating left fit, last curvature: 617.309175379  new curvature 558.267349325
# good lefts: 89
# updating right fit, last curvature: 808.4048302  new curvature 474.222419034
# good rights: 60
#  87%|████████▋ | 89/102 [00:17<00:02,  5.20it/s]
# searching from last histogram
# leftx: 10613 rightx: 1193
# updating left fit, last curvature: 558.267349325  new curvature 512.881732731
# good lefts: 90
# updating right fit, last curvature: 474.222419034  new curvature 538.517630791
# good rights: 61
# searching from last histogram
# leftx: 10464 rightx: 1347
# updating left fit, last curvature: 512.881732731  new curvature 470.989673694
# good lefts: 91
# updating right fit, last curvature: 538.517630791  new curvature 478.929420475
# good rights: 62
#  89%|████████▉ | 91/102 [00:17<00:02,  5.18it/s]
# searching from last histogram
# leftx: 10355 rightx: 1817
# updating left fit, last curvature: 470.989673694  new curvature 495.540295655
# good lefts: 92
# updating right fit, last curvature: 478.929420475  new curvature 596.385341956
# good rights: 63
# searching from last histogram
# leftx: 10210 rightx: 1912
# updating left fit, last curvature: 495.540295655  new curvature 505.083669022
# good lefts: 93
# updating right fit, last curvature: 596.385341956  new curvature 625.515974907
# good rights: 64
#  91%|█████████ | 93/102 [00:18<00:01,  5.20it/s]
# searching from last histogram
# leftx: 10269 rightx: 1677
# updating left fit, last curvature: 505.083669022  new curvature 470.056756908
# good lefts: 94
# updating right fit, last curvature: 625.515974907  new curvature 693.377122368
# good rights: 65
# searching from last histogram
# leftx: 9931 rightx: 1385
# updating left fit, last curvature: 470.056756908  new curvature 457.924748878
# good lefts: 95
# updating right fit, last curvature: 693.377122368  new curvature 882.64754075
# good rights: 66
#  93%|█████████▎| 95/102 [00:18<00:01,  5.14it/s]
# searching from last histogram
# leftx: 10200 rightx: 1016
# updating left fit, last curvature: 457.924748878  new curvature 474.119113995
# good lefts: 96
# searching from last histogram
# leftx: 10299 rightx: 789
# updating left fit, last curvature: 474.119113995  new curvature 474.276599094
# good lefts: 97
# updating right fit, last curvature: 882.64754075  new curvature 930.29632403
# good rights: 67
#  95%|█████████▌| 97/102 [00:19<00:00,  5.18it/s]
# searching from last histogram
# leftx: 10221 rightx: 951
# updating left fit, last curvature: 474.276599094  new curvature 474.853790887
# good lefts: 98
# updating right fit, last curvature: 930.29632403  new curvature 925.555418272
# good rights: 68
# searching from last histogram
# leftx: 10250 rightx: 965
# updating left fit, last curvature: 474.853790887  new curvature 488.491688034
# good lefts: 99
# updating right fit, last curvature: 925.555418272  new curvature 541.609728646
# good rights: 69
#  97%|█████████▋| 99/102 [00:19<00:00,  5.21it/s]
# searching from last histogram
# leftx: 10095 rightx: 1088
# updating left fit, last curvature: 488.491688034  new curvature 480.703642665
# good lefts: 100
# updating right fit, last curvature: 541.609728646  new curvature 869.314996148
# good rights: 70
# searching from last histogram
# leftx: 10308 rightx: 1321
# updating left fit, last curvature: 480.703642665  new curvature 493.403615685
# good lefts: 101
# updating right fit, last curvature: 869.314996148  new curvature 904.967001346
# good rights: 71
#  99%|█████████▉| 101/102 [00:19<00:00,  5.17it/s]
# searching from last histogram
# leftx: 10331 rightx: 1397
# updating left fit, last curvature: 493.403615685  new curvature 488.49092192
# good lefts: 102
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: project_video_output_4s.mp4
#
# CPU times: user 32.7 s, sys: 403 ms, total: 33.1 s
# Wall time: 20.4 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(output))
# Out:
# <video width="960" height="540" controls>
#   <source src="project_video_output_4s.mp4">
# </video>
